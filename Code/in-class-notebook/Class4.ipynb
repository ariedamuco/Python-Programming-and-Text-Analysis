# %%
pwd
# Out:
# '/Users/ariedamuco/Dropbox (CEU Econ)/TextAnalysisCEU'

# %%
import os

# %%
os.chdir("/Users/ariedamuco/Dropbox (CEU Econ)/TextAnalysisCEU")

# %%
nltk= open("Inputs/nltk_stopwords.txt", 'r')

# %%
nltk
# Out:
# <_io.TextIOWrapper name='Inputs/nltk_stopwords.txt' mode='r' encoding='UTF-8'>

# %%
nltk_stopwords = []

# %%
nltk_stopwords
# Out:
# []

# %%
for i in nltk.readlines():
    i = i.replace("\n","")
    nltk_stopwords.append(i)

# %%
print(nltk_stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
import pandas as pd
europe = pd.read_html("https://insights.invyo.io/europe/mapping/the-european-top-50-of-the-most-valued-fintech/")

# %%
type(europe)
# Out:
# list

# %%
len(europe)
# Out:
# 1

# %%
top_fintec_europe = europe[0]

# %%
top_fintec_europe
# Out:
#     Ranking               Name Valuation      Country  \
# 0         1              Adyen     $8.3B  Netherlands
# 1         2               Nexi     $8.2B        Italy
# 2         3             Klarna     $5.5B       Sweden
# 3         4          Greensill     $3.5B           UK
# 4         5       Transferwise     $3.5B           UK
# 5         6                N26     $3.5B      Germany
# 6         7           Oaknorth     $2.8B           UK
# 7         8              Monzo     $2.5B           UK
# 8         9     Funding Circle     $2.4B           UK
# 9        10            Izettle     $2.2B       Sweden
# 10       11           Checkout       $2B           UK
# 11       12          Darktrace     $1.7B           UK
# 12       13            Revolut     $1.7B           UK
# 13       14              Sumup    >$1.0B           UK
# 14       15             Avaloq     $1.0B  Switzerland
# 15       16     Radius Payment     $1.0B           UK
# ...
